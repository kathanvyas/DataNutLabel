# %%
from pretty_html_table import build_table
import pandas as pd

# %%
df = pd.read_csv('C:/Users/kathan_vyas/OneDrive - Edwards Lifesciences/Desktop/eCEC/MI_local/myocardial_partner3_06292022.csv')
ddf = df[['CEC_AUTORELDS','CEC_AUTORELSV']].describe()
ddf.reset_index(inplace=True)
ddf2 = df[['CEC_VISNAME','AE_AEPRCDUR']].describe()
ddf2.reset_index(inplace=True)

# %%
#df = pd.read_csv('C:/Users/kathan_vyas/OneDrive - Edwards Lifesciences/Desktop/eCEC/MI_local/pred_csv/test_pred_catb.csv')
html_table_blue_light = build_table(ddf, 'blue_light')
html_table_org_light = build_table(ddf2, 'blue_dark')
filename = 'File Name : myocardial_partner3_06292022.csv'

# Save to html file
with open('pretty_table.html', 'w') as f:
    f.write("<html>\n<head>\n<title> \nOutput Data in an HTML file \
           </title>\n</head> <body><h1><font color = #00b300>\nData Label</font></h1>\
           \n<h2>The table below shows description for few columns</h2> \n</body></html>")
    f.write(filename)
    f.write("<html> <body><h3>Categorical Variables<u></u></h3>\n</body></html>")       
    f.write(html_table_blue_light)
    f.write("<html> <body><h3>Numerical Variables<u></u></h3>\n</body></html>")    
    f.write(html_table_org_light)
    

# # Compare to the pandas .to_html method:
# with open('pandas_table.html', 'w') as f:
#     f.write(ddf.to_html())

# %%
#this is inline example
from IPython.core.display import display, HTML
display(HTML('<html>\n<head>\n<title> \nOutput Data in an HTML file \
           </title>\n</head> <body><h1><font color = #00b300>\nData Label</font></h1>\
           \n<h2>The table below shows description for few columns</h2> \n</body></html>'))
display(HTML('<html> <body><h3>Categorical Variables<u></u></h3>\n</body></html>'))           
HTML(html_table_blue_light)
# Out:
# C:\Users\kathan_vyas\AppData\Local\Temp\ipykernel_29352\1046050859.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <html>
# <head>
# <title>
# Output Data in an HTML file            </title>
# </head> <body><h1><font color = #00b300>
# Data Label</font></h1>
# <h2>The table below shows description for few columns</h2>
# </body></html>
# <html> <body><h3>Categorical Variables<u></u></h3>
# </body></html>
# <p><table border="0" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">index</th>
# ...

# %%
def df_col_summary(df,column_name,flag='c'):
    sum_df1 = df.column_name.describe()
    sum_df2 = df.nunique()
    if flag=='c':
        print(df.column_name.value_counts())
    f.write("<html>\n<head>\n<title> \nOutput Data in an HTML file \
           </title>\n</head> <body><h1><font color = #00b300>\nData Label</font></h1>\
           \n<h2>The table below shows description for few columns</h2> \n</body></html>")
    f.write(filename)
    f.write("<html> <body><h3>Categorical Variables<u></u></h3>\n</body></html>")       
    f.write(html_table_blue_light)
    f.write("<html> <body><h3>Numerical Variables<u></u></h3>\n</body></html>")    
    f.write(html_table_org_light)
def df_summaryar(df):
    from IPython.core.display import display, HTML
    display(HTML('<html>\n<head>\n<title> \nOutput Data in an HTML file \
            </title>\n</head> <body><h1><font color = #00b300>\nData Label</font></h1>\
            \n<h2>The table below shows description for few columns</h2> \n</body></html>'))
    display(HTML('<html> <body><h3>Categorical Variables<u></u></h3>\n</body></html>'))           
    HTML(html_table_blue_light)

# %%
import numpy as np
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_61c47">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_61c47_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_61c47_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_61c47_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_61c47_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_61c47_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_61c47_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_61c47_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_61c47_level1_col4" class="col_heading level1 col4" >Tumour</th>
# ...

# %%
df.style.format(precision=0, na_rep='MISSING', thousands=" ",
                formatter={('Decision Tree', 'Tumour'): "{:.2f}",
                           ('Regression', 'Non-Tumour'): lambda x: "$ {:,.1f}".format(x*-1e6)
                          })
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac9b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_ac9b0_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_ac9b0_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_ac9b0_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_ac9b0_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_ac9b0_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_ac9b0_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_ac9b0_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_ac9b0_level1_col4" class="col_heading level1 col4" >Tumour</th>
# ...

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  4.698685  2.945186
# 2021-01-02  4.738512  1.807463
# 2021-01-03  4.521205  0.960673
# 2021-01-04  1.645005  0.570727
# 2021-01-05  2.725032  1.247885
# 2021-01-06  0.386564  1.331349
# 2021-01-07  2.639724  0.104643
# 2021-01-08  4.209507  2.766521
# 2021-01-09  1.508289  0.354665
# 2021-01-10  2.208551  2.684730

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_28ade_row0_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_28ade_row0_col1, #T_28ade_row2_col0, #T_28ade_row3_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_28ade_row1_col0 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_28ade_row1_col1 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_28ade_row2_col1 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_28ade_row3_col0 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_28ade_row4_col0 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_28ade_row4_col1 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# </style>
# <table id="T_28ade">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28ade_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_28ade_level0_col1" class="col_heading level0 col1" >Beijing</th>
# ...

# %%
s = df.style.format('{:.0f}').hide([('Random', 'Tumour'), ('Random', 'Non-Tumour')], axis="columns")
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_fb9e4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_fb9e4_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_fb9e4_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_fb9e4_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_fb9e4_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_fb9e4_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_fb9e4_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
s.set_table_styles([
    {'selector': 'th.col_heading', 'props': 'text-align: center;'},
    {'selector': 'th.col_heading.level0', 'props': 'font-size: 1.5em;'},
    {'selector': 'td', 'props': 'text-align: center; font-weight: bold;'},
], overwrite=False)
# Out:
# <style type="text/css">
# #T_fb9e4 th.col_heading {
#   text-align: center;
# }
# #T_fb9e4 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_fb9e4 td {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_fb9e4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_fb9e4_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_fb9e4_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_fb9e4_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_fb9e4_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_fb9e4_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_fb9e4_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
# ...

# %%
cell_hover = {  # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000066; color: white;'
}
s.set_table_styles([cell_hover, index_names, headers])
# Out:
# <style type="text/css">
# #T_fb9e4 td:hover {
#   background-color: #ffffb3;
# }
# #T_fb9e4 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_fb9e4 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# </style>
# <table id="T_fb9e4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_fb9e4_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_fb9e4_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_fb9e4_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_fb9e4_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_fb9e4_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_fb9e4_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
# ...

# %%
s.set_table_styles([  # create internal CSS classes
    {'selector': '.true', 'props': 'background-color: #e6ffe6;'},
    {'selector': '.false', 'props': 'background-color: #ffe6e6;'},
], overwrite=False)
cell_color = pd.DataFrame([['true ', 'false ', 'true ', 'false '],
                           ['false ', 'true ', 'false ', 'true ']],
                          index=df.index,
                          columns=df.columns[:4])
s.set_td_classes(cell_color)
# Out:
# <style type="text/css">
# #T_fb9e4 td:hover {
#   background-color: #ffffb3;
# }
# #T_fb9e4 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_fb9e4 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_fb9e4 .true {
#   background-color: #e6ffe6;
# }
# #T_fb9e4 .false {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_fb9e4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_fb9e4_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_fb9e4_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_fb9e4_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_fb9e4_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
# ...

# %%
np.random.seed(0)
df2 = pd.DataFrame(np.random.randn(10,4), columns=['A','B','C','D'])
df2.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7eb04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eb04_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7eb04_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7eb04_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_7eb04_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eb04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7eb04_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_7eb04_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_7eb04_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_7eb04_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_7eb04_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
s2 = df2.style.applymap(style_negative, props='color:red;')\
              .applymap(lambda v: 'opacity: 20%;' if (v < 0.3) and (v > -0.3) else None)
s2
# Out:
# <style type="text/css">
# #T_c1e24_row1_col1, #T_c1e24_row4_col3, #T_c1e24_row5_col0, #T_c1e24_row5_col3, #T_c1e24_row6_col1, #T_c1e24_row8_col0, #T_c1e24_row8_col1, #T_c1e24_row8_col2, #T_c1e24_row9_col2, #T_c1e24_row9_col3 {
#   color: red;
# }
# #T_c1e24_row1_col3, #T_c1e24_row2_col0, #T_c1e24_row4_col1, #T_c1e24_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_c1e24_row2_col2, #T_c1e24_row3_col1, #T_c1e24_row6_col2, #T_c1e24_row7_col2, #T_c1e24_row8_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_c1e24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1e24_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_c1e24_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_c1e24_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_c1e24_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')
s2.apply(highlight_max, props='color:white;background-color:darkblue', axis=0)
# Out:
# <style type="text/css">
# #T_c1e24_row0_col2, #T_c1e24_row0_col3, #T_c1e24_row6_col0, #T_c1e24_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_c1e24_row1_col1, #T_c1e24_row4_col3, #T_c1e24_row5_col0, #T_c1e24_row5_col3, #T_c1e24_row6_col1, #T_c1e24_row8_col0, #T_c1e24_row8_col1, #T_c1e24_row8_col2, #T_c1e24_row9_col2, #T_c1e24_row9_col3 {
#   color: red;
# }
# #T_c1e24_row1_col3, #T_c1e24_row2_col0, #T_c1e24_row4_col1, #T_c1e24_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_c1e24_row2_col2, #T_c1e24_row3_col1, #T_c1e24_row6_col2, #T_c1e24_row7_col2, #T_c1e24_row8_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_c1e24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1e24_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_c1e24_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_c1e24_level0_col2" class="col_heading level0 col2" >C</th>
# ...

# %%
s2.apply(highlight_max, props='color:white;background-color:pink;', axis=1)\
  .apply(highlight_max, props='color:white;background-color:purple', axis=None)
# Out:
# <style type="text/css">
# #T_c1e24_row0_col2, #T_c1e24_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_c1e24_row0_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
# }
# #T_c1e24_row1_col0, #T_c1e24_row2_col3, #T_c1e24_row3_col0, #T_c1e24_row4_col0, #T_c1e24_row5_col2, #T_c1e24_row7_col0, #T_c1e24_row9_col0 {
#   color: white;
#   background-color: pink;
# }
# #T_c1e24_row1_col1, #T_c1e24_row4_col3, #T_c1e24_row5_col0, #T_c1e24_row5_col3, #T_c1e24_row6_col1, #T_c1e24_row8_col0, #T_c1e24_row8_col1, #T_c1e24_row8_col2, #T_c1e24_row9_col2, #T_c1e24_row9_col3 {
#   color: red;
# }
# #T_c1e24_row1_col3, #T_c1e24_row2_col0, #T_c1e24_row4_col1, #T_c1e24_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_c1e24_row2_col2, #T_c1e24_row3_col1, #T_c1e24_row6_col2, #T_c1e24_row7_col2 {
#   opacity: 20%;
# }
# #T_c1e24_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
# ...

# %%
s2.applymap_index(lambda v: "color:pink;" if v>4 else "color:darkblue;", axis=0)
s2.apply_index(lambda s: np.where(s.isin(["A", "B"]), "color:pink;", "color:darkblue;"), axis=1)
# Out:
# <style type="text/css">
# #T_c1e24_row0_col2, #T_c1e24_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_c1e24_row0_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
# }
# #T_c1e24_row1_col0, #T_c1e24_row2_col3, #T_c1e24_row3_col0, #T_c1e24_row4_col0, #T_c1e24_row5_col2, #T_c1e24_row7_col0, #T_c1e24_row9_col0 {
#   color: white;
#   background-color: pink;
# }
# #T_c1e24_row1_col1, #T_c1e24_row4_col3, #T_c1e24_row5_col0, #T_c1e24_row5_col3, #T_c1e24_row6_col1, #T_c1e24_row8_col0, #T_c1e24_row8_col1, #T_c1e24_row8_col2, #T_c1e24_row9_col2, #T_c1e24_row9_col3 {
#   color: red;
# }
# #T_c1e24_row1_col3, #T_c1e24_row2_col0, #T_c1e24_row4_col1, #T_c1e24_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_c1e24_row2_col2, #T_c1e24_row3_col1, #T_c1e24_row6_col2, #T_c1e24_row7_col2 {
#   opacity: 20%;
# }
# #T_c1e24_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
# ...

# %%
df3 = pd.DataFrame(np.random.randn(4,4),
                   pd.MultiIndex.from_product([['A', 'B'], ['r1', 'r2']]),
                   columns=['c1','c2','c3','c4'])
df3
# Out:
#             c1        c2        c3        c4
# A r1 -1.048553 -1.420018 -1.706270  1.950775
#   r2 -0.509652 -0.438074 -1.252795  0.777490
# B r1 -1.613898 -0.212740 -0.895467  0.386902
#   r2 -0.510805 -1.180632 -0.028182  0.428332

# %%
df2.loc[:4].style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style type="text/css">
# #T_92ac7_row0_col0, #T_92ac7_row0_col1, #T_92ac7_row0_col2, #T_92ac7_row0_col3, #T_92ac7_row1_col0, #T_92ac7_row1_col1, #T_92ac7_row1_col2, #T_92ac7_row1_col3, #T_92ac7_row2_col0, #T_92ac7_row2_col1, #T_92ac7_row2_col2, #T_92ac7_row2_col3, #T_92ac7_row3_col0, #T_92ac7_row3_col1, #T_92ac7_row3_col2, #T_92ac7_row3_col3, #T_92ac7_row4_col0, #T_92ac7_row4_col1, #T_92ac7_row4_col2, #T_92ac7_row4_col3 {
#   background-color: black;
#   color: lawngreen;
#   border-color: white;
# }
# </style>
# <table id="T_92ac7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92ac7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_92ac7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_92ac7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_92ac7_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df2.style.bar(subset=['A', 'B'], color='#d65f5f')
# Out:
# <style type="text/css">
# #T_67de8_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 52.9%, #d65f5f 52.9%, #d65f5f 89.5%, transparent 89.5%);
# }
# #T_67de8_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 57.4%, #d65f5f 57.4%, #d65f5f 69.0%, transparent 69.0%);
# }
# #T_67de8_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 52.9%, #d65f5f 52.9%, #d65f5f 91.7%, transparent 91.7%);
# }
# #T_67de8_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.1%, #d65f5f 29.1%, #d65f5f 57.4%, transparent 57.4%);
# }
# #T_67de8_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.8%, #d65f5f 50.8%, #d65f5f 52.9%, transparent 52.9%);
# }
# #T_67de8_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 57.4%, #d65f5f 57.4%, #d65f5f 69.3%, transparent 69.3%);
# }
# #T_67de8_row3_col0 {
#   width: 10em;
# ...

# %%
df2.style.format('{:.3f}', na_rep="")\
         .bar(align=0, vmin=-2.5, vmax=2.5, cmap="bwr", height=50,
              width=60, props="width: 120px; border-right: 1px solid black;")\
         .text_gradient(cmap="bwr", vmin=-2.5, vmax=2.5)
# Out:
# <style type="text/css">
# #T_16d32_row0_col0 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ff4a4a 30.0%, #ff4a4a 51.2%, transparent 51.2%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ff4a4a;
# }
# #T_16d32_row0_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ffd6d6 30.0%, #ffd6d6 34.8%, transparent 34.8%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ffd6d6;
# }
# #T_16d32_row0_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #ff9a9a 30.0%, #ff9a9a 41.7%, transparent 41.7%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ff9a9a;
# }
# #T_16d32_row0_col3 {
#   width: 120px;
#   border-right: 1px solid black;
# ...

# %%
HTML(head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\kathan_vyas\OneDrive - Edwards Lifesciences\Desktop\data_nut_label\test.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kathan_vyas/OneDrive%20-%20Edwards%20Lifesciences/Desktop/data_nut_label/test.ipynb#ch0000004?line=0'>1</a> HTML(head)
#
# NameError: name 'HTML' is not defined
